# %%
# notes: 
# print _______ for the amount of letters (prob len(letters))
# fill in the letter at the exact location
# import a bigger list

# %% [markdown]
# # To Start The Game: Run The Code Block Below

# %%
# Load a new game
# lists & libraries
import pandas as pd
import random
import time
file = pd.read_excel(r"F:\Python\Hangman_list.xlsx")
library = file["Living_Room"].tolist()
wrong_guesses = []
right_guesses = []

# Game conditions and settings
the_word = random.choice(library)
letters = [letter for letter in the_word]
starting_lives = 7
lives = 7

print("Let's Start Playing Guess The Word!")
print(f"You can make {starting_lives} mistakes.")
print(f"Your word has {len(letters)} letters")
# Out:
# Let's Start Playing Guess The Word!
# You can make 7 mistakes.
# Your word has 4 letters

# %% [markdown]
# ### Enter Your Guesses By Running The Block Below

# %%
# Guess a letter
def Guesses(lives):
    if lives >= 1:
        guess = input("Enter your choice of letter:")
        return guess
    elif lives <= 0:
       pass

def list_updater(guess):
    if guess in letters:
        right_guesses.append(guess)
    else:
        wrong_guesses.append(guess)

def lives_updater(guess):
  if guess in letters:
    pass
  else:
    global lives
    lives -=1

def gallow_status(lives):
    if lives == 7:
      print ("__________")
      print ("|/        ")
      print ("|         ")
      print ("|         ")
      print ("|         ")
 
    elif lives == 6:
      print ("__________")
      print ("|/     |  ")
      print ("|         ")
      print ("|         ")
      print ("|         ")

    elif lives == 5:
      print ("__________")
      print ("|/     |  ")
      print ("|      O  ")
      print ("|         ")
      print ("|         ")
       
    elif lives == 4:
      print ("__________")
      print ("|/     |  ")
      print ("|     \O  ")
      print ("|         ")
      print ("|         ")
       
    elif lives == 3:
      print ("__________")
      print ("|/     |  ")
      print ("|     \O/ ")
      print ("|         ")
      print ("|         ")
       
    elif lives == 2:
      print ("__________")
      print ("|/     |  ")
      print ("|     \O/ ")
      print ("|      |  ")
      print ("|         ")
       
    elif lives == 1:
      print ("__________")
      print ("|/     |  ")
      print ("|     \O/ ")
      print ("|      |  ")
      print ("|     /   ")

    elif lives == 0:
      print ( "__________")
      print ( "|/     |  ")
      print ( "|     \O/ ")
      print ( "|      |  ")
      print ( "|     / \ ")

if lives >= 2:
  guess = Guesses(lives)
  list_updater(guess)
  lives_updater(guess)
  gallow_status(lives)

  if guess in letters:   
      print(f'Your correct guesses:{right_guesses}')
      print(f'Your wrong guesses:{wrong_guesses}')
      print(f'You have {lives} more lives left')
  else:
      print(f'Your correct guesses:{right_guesses}')
      print(f'Your wrong guesses:{wrong_guesses}')
      print(f'You have {lives} more lives left')
elif lives == 1:
  guess = Guesses(lives)
  list_updater(guess)
  lives_updater(guess)
  gallow_status(lives)

  if guess in letters:   
      print(f'Your correct guesses:{right_guesses}')
      print(f'Your wrong guesses:{wrong_guesses}')
      print(f'You have {lives} more lives left')
  else:
    print(" ██████╗  █████╗ ███╗   ███╗███████╗     ██████╗ ██╗   ██╗███████╗██████╗ ")
    print("██╔════╝ ██╔══██╗████╗ ████║██╔════╝    ██╔═══██╗██║   ██║██╔════╝██╔══██╗")
    print("██║  ███╗███████║██╔████╔██║█████╗      ██║   ██║██║   ██║█████╗  ██████╔╝")
    print("██║   ██║██╔══██║██║╚██╔╝██║██╔══╝      ██║   ██║╚██╗ ██╔╝██╔══╝  ██╔══██╗")
    print("╚██████╔╝██║  ██║██║ ╚═╝ ██║███████╗    ╚██████╔╝ ╚████╔╝ ███████╗██║  ██║")
    print(" ╚═════╝ ╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝     ╚═════╝   ╚═══╝  ╚══════╝╚═╝  ╚═╝")
    print("")
    print(f"The Correct Answer was: {the_word}")
elif lives == 0:
  print(" ██████╗  █████╗ ███╗   ███╗███████╗     ██████╗ ██╗   ██╗███████╗██████╗ ")
  print("██╔════╝ ██╔══██╗████╗ ████║██╔════╝    ██╔═══██╗██║   ██║██╔════╝██╔══██╗")
  print("██║  ███╗███████║██╔████╔██║█████╗      ██║   ██║██║   ██║█████╗  ██████╔╝")
  print("██║   ██║██╔══██║██║╚██╔╝██║██╔══╝      ██║   ██║╚██╗ ██╔╝██╔══╝  ██╔══██╗")
  print("╚██████╔╝██║  ██║██║ ╚═╝ ██║███████╗    ╚██████╔╝ ╚████╔╝ ███████╗██║  ██║")
  print(" ╚═════╝ ╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝     ╚═════╝   ╚═══╝  ╚══════╝╚═╝  ╚═╝")
#guess_the_word = input("Would you like to guess the word? Type: Y/N")
# Out:
#  ██████╗  █████╗ ███╗   ███╗███████╗     ██████╗ ██╗   ██╗███████╗██████╗
# ██╔════╝ ██╔══██╗████╗ ████║██╔════╝    ██╔═══██╗██║   ██║██╔════╝██╔══██╗
# ██║  ███╗███████║██╔████╔██║█████╗      ██║   ██║██║   ██║█████╗  ██████╔╝
# ██║   ██║██╔══██║██║╚██╔╝██║██╔══╝      ██║   ██║╚██╗ ██╔╝██╔══╝  ██╔══██╗
# ╚██████╔╝██║  ██║██║ ╚═╝ ██║███████╗    ╚██████╔╝ ╚████╔╝ ███████╗██║  ██║
#  ╚═════╝ ╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝     ╚═════╝   ╚═══╝  ╚══════╝╚═╝  ╚═╝

# %% [markdown]
# ### If You Want To Guess The Word, Run The Cell Below

# %%
# guess the word
guess_the_word = input("Enter The Word:")

if guess_the_word == the_word:
    print('processing....')
    time.sleep(5)
    print("just a bit longer...")
    time.sleep(3)
    print("Please stop staring.... it's weird.")
    time.sleep(3)
    print("....")
    time.sleep(2)
    print("Ugh, Fine")
    time.sleep(1)
    print(f'{guess_the_word} IS RIGHT, YOU WIN THE GAME! WELL DONE!')
    time.sleep(2)
    print("I hope it was worth it....")
    time.sleep(1)
    print("██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗██╗███╗   ██╗██╗")
    print("╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██║████╗  ██║██║")
    print(" ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║██╔██╗ ██║██║")
    print("  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║██║╚██╗██║╚═╝")
    print("   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝██║██║ ╚████║██╗")
    print("   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝ ╚═╝╚═╝  ╚═══╝╚═╝")


else:
    print('processing....')
    time.sleep(5)
    print("just a bit longer...")
    time.sleep(3)
    print("Please stop staring.... it's weird.")
    time.sleep(3)
    print("....")
    time.sleep(2)
    print("Ugh, Fine")
    time.sleep(1)
    print(f"{guess_the_word} is not the correct word...")
    time.sleep(2)
    print("you gambled it all... and lost")
    time.sleep(2)
    print("Sad really...")
    time.sleep(1)
    print("██╗   ██╗ ██████╗ ██╗   ██╗    ███████╗██╗   ██╗ ██████╗██╗  ██╗")
    print("╚██╗ ██╔╝██╔═══██╗██║   ██║    ██╔════╝██║   ██║██╔════╝██║ ██╔╝")
    print(" ╚████╔╝ ██║   ██║██║   ██║    ███████╗██║   ██║██║     █████╔╝ ")
    print("  ╚██╔╝  ██║   ██║██║   ██║    ╚════██║██║   ██║██║     ██╔═██╗ ")
    print("   ██║   ╚██████╔╝╚██████╔╝    ███████║╚██████╔╝╚██████╗██║  ██╗")
    print("   ╚═╝    ╚═════╝  ╚═════╝     ╚══════╝ ╚═════╝  ╚═════╝╚═╝  ╚═╝")
